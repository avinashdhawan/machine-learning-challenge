# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\avina\onedrive\desktop\ml_env\venv\lib\site-packages (0.16.0)
# You are using pip version 19.0.3, however version 20.2b1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# Set the seed value for the notebook so the results are reproducible
from numpy.random import seed
seed(42)

# %%
import pandas as pd
import numpy as np

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
df = df.loc[:,~df.columns.str.contains('err')]
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_time0bk  koi_impact  koi_duration  \
# 0                 0   54.418383   162.513840       0.586       4.50700
# 1                 0   19.899140   175.850252       0.969       1.78220
# 2                 0    1.736952   170.307565       1.276       2.40641
# 3                 0    2.525592   171.595550       0.701       1.65450
# 4                 0    4.134435   172.979370       0.762       3.14020
# ...             ...         ...          ...         ...           ...
# 6986              1    8.589871   132.016100       0.765       4.80600
# 6987              0    0.527699   131.705093       1.252       3.22210
# 6988              0    1.739849   133.001270       0.043       3.11400
# 6989              0    0.681402   132.181750       0.147       0.86500
# 6990              1    4.856035   135.993300       0.134       3.07800
#
#       koi_depth  ...  koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  \
# 0         874.8  ...      443       9.11           25.8                 2
# 1       10829.0  ...      638      39.30           76.3                 1
# 2        8079.2  ...     1395     891.96          505.6                 1
# 3         603.3  ...     1406     926.16           40.9                 1
# 4         686.0  ...     1160     427.65           40.2                 2
# ...         ...  ...      ...        ...            ...               ...
# 6986       87.7  ...      929     176.40            8.4                 1
# 6987     1579.2  ...     2088    4500.53          453.3                 1
# 6988       48.5  ...     1608    1585.81           10.6                 1
# 6989      103.6  ...     2218    5713.41           12.3                 1
# 6990       76.7  ...     1266     607.42            8.2                 1
#
#       koi_steff  koi_slogg  koi_srad         ra        dec  koi_kepmag
# 0          5455      4.467     0.927  291.93423  48.141651      15.347
# 1          5853      4.544     0.868  297.00482  48.134129      15.436
# 2          5805      4.564     0.791  285.53461  48.285210      15.597
# 3          6031      4.438     1.046  288.75488  48.226200      15.509
# 4          6046      4.486     0.972  296.28613  48.224670      15.714
# ...         ...        ...       ...        ...        ...         ...
# 6986       5638      4.296     1.088  298.74921  46.973351      14.478
# 6987       5638      4.529     0.903  297.18875  47.093819      14.082
# 6988       6119      4.444     1.031  286.50937  47.163219      14.757
# 6989       6173      4.447     1.041  294.16489  47.176281      15.385
# 6990       6469      4.385     1.193  297.00977  47.121021      14.826
#
# [6991 rows x 21 columns]

# %%
df = df.round()
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_time0bk  koi_impact  koi_duration  \
# 0                 0        54.0        163.0         1.0           5.0
# 1                 0        20.0        176.0         1.0           2.0
# 2                 0         2.0        170.0         1.0           2.0
# 3                 0         3.0        172.0         1.0           2.0
# 4                 0         4.0        173.0         1.0           3.0
# ...             ...         ...          ...         ...           ...
# 6986              1         9.0        132.0         1.0           5.0
# 6987              0         1.0        132.0         1.0           3.0
# 6988              0         2.0        133.0         0.0           3.0
# 6989              0         1.0        132.0         0.0           1.0
# 6990              1         5.0        136.0         0.0           3.0
#
#       koi_depth  ...  koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  \
# 0         875.0  ...      443        9.0           26.0                 2
# 1       10829.0  ...      638       39.0           76.0                 1
# 2        8079.0  ...     1395      892.0          506.0                 1
# 3         603.0  ...     1406      926.0           41.0                 1
# 4         686.0  ...     1160      428.0           40.0                 2
# ...         ...  ...      ...        ...            ...               ...
# 6986       88.0  ...      929      176.0            8.0                 1
# 6987     1579.0  ...     2088     4501.0          453.0                 1
# 6988       48.0  ...     1608     1586.0           11.0                 1
# 6989      104.0  ...     2218     5713.0           12.0                 1
# 6990       77.0  ...     1266      607.0            8.0                 1
#
#       koi_steff  koi_slogg  koi_srad     ra   dec  koi_kepmag
# 0          5455        4.0       1.0  292.0  48.0        15.0
# 1          5853        5.0       1.0  297.0  48.0        15.0
# 2          5805        5.0       1.0  286.0  48.0        16.0
# 3          6031        4.0       1.0  289.0  48.0        16.0
# 4          6046        4.0       1.0  296.0  48.0        16.0
# ...         ...        ...       ...    ...   ...         ...
# 6986       5638        4.0       1.0  299.0  47.0        14.0
# 6987       5638        5.0       1.0  297.0  47.0        14.0
# 6988       6119        4.0       1.0  287.0  47.0        15.0
# 6989       6173        4.0       1.0  294.0  47.0        15.0
# 6990       6469        4.0       1.0  297.0  47.0        15.0
#
# [6991 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.corr()
# Out:
#                   koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# koi_fpflag_nt          1.000000      -0.241148       0.003062       0.050790
# koi_fpflag_ss         -0.241148       1.000000       0.144516       0.101695
# koi_fpflag_co          0.003062       0.144516       1.000000       0.538280
# koi_fpflag_ec          0.050790       0.101695       0.538280       1.000000
# koi_period             0.408819      -0.155908      -0.164750      -0.138891
# koi_time0bk            0.249469      -0.111486      -0.121262      -0.099530
# koi_impact             0.069553       0.039613       0.002686      -0.005639
# koi_duration           0.286405       0.013946      -0.048466       0.022974
# koi_depth             -0.043942       0.423883      -0.132939      -0.088001
# koi_prad               0.054410      -0.000752      -0.013283      -0.011076
# koi_teq               -0.003013       0.191842       0.259045       0.218624
# koi_insol             -0.000566       0.031315       0.018086       0.034874
# koi_model_snr         -0.079239       0.439767      -0.134486      -0.091912
# koi_tce_plnt_num       0.035902      -0.184721      -0.122911      -0.103976
# koi_steff              0.105008       0.104600       0.016750       0.012411
# koi_slogg             -0.078564      -0.021964       0.022955       0.027191
# koi_srad               0.044848       0.033554       0.033490       0.023529
# ra                     0.032267       0.087262       0.160264       0.071688
# dec                   -0.043852      -0.053918      -0.091351      -0.040487
# koi_kepmag            -0.098969      -0.005392       0.071667       0.052565
#
#                   koi_period  koi_time0bk  koi_impact  koi_duration  \
# koi_fpflag_nt       0.408819     0.249469    0.069553      0.286405
# koi_fpflag_ss      -0.155908    -0.111486    0.039613      0.013946
# koi_fpflag_co      -0.164750    -0.121262    0.002686     -0.048466
# koi_fpflag_ec      -0.138891    -0.099530   -0.005639      0.022974
# koi_period          1.000000     0.655087    0.064922      0.324406
# koi_time0bk         0.655087     1.000000    0.054347      0.200755
# koi_impact          0.064922     0.054347    1.000000      0.036927
# koi_duration        0.324406     0.200755    0.036927      1.000000
# koi_depth          -0.064265    -0.037150    0.003381      0.072758
# koi_prad            0.072806     0.039855    0.735413      0.041108
# koi_teq            -0.389803    -0.315278   -0.014725     -0.182941
# koi_insol          -0.021675    -0.021246   -0.003669     -0.017003
# koi_model_snr      -0.081480    -0.058538    0.000889      0.073240
# ra                       -0.036858   0.111845  -0.062658  0.038211  1.000000
# dec                       0.027277  -0.041288   0.044117 -0.033133 -0.023689
# koi_kepmag               -0.051089  -0.329739   0.423624 -0.162027  0.004695
#
#                        dec  koi_kepmag
# koi_fpflag_nt    -0.043852   -0.098969
# koi_fpflag_ss    -0.053918   -0.005392
# koi_fpflag_co    -0.091351    0.071667
# koi_fpflag_ec    -0.040487    0.052565
# koi_period        0.012169   -0.044330
# koi_time0bk       0.010070    0.020765
# koi_impact        0.000230   -0.005834
# koi_duration     -0.033357   -0.096852
# koi_depth        -0.016754    0.002398
# koi_prad          0.004381   -0.025406
# koi_teq          -0.061397   -0.258560
# koi_insol        -0.015861   -0.068316
# koi_model_snr    -0.001452   -0.125966
# koi_tce_plnt_num  0.027277   -0.051089
# koi_steff        -0.041288   -0.329739
# koi_slogg         0.044117    0.423624
# koi_srad         -0.033133   -0.162027
# ra               -0.023689    0.004695
# dec               1.000000    0.019341
# koi_kepmag        0.019341    1.000000

# %%
plt.matshow(df.corr());
plt.colorbar();

# %%
# df.rename(columns = {"koi_disposition": "Disposition", 'koi_fpflag_nt': "NotTransit", "koi_fpflag_ss":"Stellar Eclipse", "koi_fpflag_co":"Centroid Offset", "koi_fpflag_ec":"Ephemeris Match"})

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
selected_features = df[["koi_disposition", "koi_fpflag_nt", "koi_fpflag_ss", "koi_fpflag_co", "koi_fpflag_ec", "koi_prad"  ]]
selected_features
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_prad
# 0                 0       3.0
# 1                 0      15.0
# 2                 0      33.0
# 3                 0       3.0
# 4                 0       3.0
# ...             ...       ...
# 6986              1       1.0
# 6987              0      29.0
# 6988              0       1.0
# 6989              0       1.0
# 6990              1       1.0
#
# [6991 rows x 6 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X = selected_features.drop(["koi_disposition"], axis=1)
y = selected_features["koi_disposition"]
print(X.shape, y.shape)
# Out:
# (6991, 5) (6991,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_prad
# 3563              0              0              0              0       4.0
# 4099              0              0              0              0       2.0
# 5460              0              0              0              0      15.0
# 1091              0              0              0              0       2.0
# 5999              0              0              0              0       2.0

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# # Step 1: Label-encode data set
# label_encoder = LabelEncoder()
# label_encoder.fit(y_train)
# encoded_y_train = label_encoder.transform(y_train)
# encoded_y_test = label_encoder.transform(y_test)

# %%
# # Step 2: Convert encoded labels to one-hot-encoding
# y_train_categorical = to_categorical(encoded_y_train)
# y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel="rbf")
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.4949456418081251
# Testing Data Score: 0.5200228832951945

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV

param_grid = {'C': [100, 10], 'gamma': [0.01, 0.001], 'kernel': ['rbf']}



grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.781, total=   0.6s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.796, total=   0.8s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.793, total=   0.6s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.806, total=   1.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.811, total=   0.7s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.785, total=   0.7s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.794, total=   0.9s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.800, total=   0.9s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.803, total=   0.9s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.809, total=   1.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.773, total=   0.4s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.794, total=   0.4s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.793, total=   0.4s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.802, total=   0.4s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.802, total=   0.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.742, total=   0.5s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.754, total=   0.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.743, total=   0.5s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.749, total=   0.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.746, total=   0.4s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   12.3s finished
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [100, 10], 'gamma': [0.01, 0.001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.7982102183831931

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'avinash_dhawan.sav'
joblib.dump(model, filename)
# Out:
# ['avinash_dhawan.sav']
